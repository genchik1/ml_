# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(12,8)})

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./titanic.csv', header=0)
df = df.drop(['Name', 'Ticket', 'Cabin', 'Parch'], axis=1)
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Sex'] = df['Sex'].map(lambda x: 1 if x == 'male' else 0)
df = df.dropna()
df = pd.get_dummies(df, columns=['Embarked'], dummy_na=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    889 non-null int64
# Survived       889 non-null int64
# Pclass         889 non-null int64
# Sex            889 non-null int64
# Age            889 non-null float64
# SibSp          889 non-null int64
# Fare           889 non-null float64
# Embarked_C     889 non-null uint8
# Embarked_Q     889 non-null uint8
# Embarked_S     889 non-null uint8
# dtypes: float64(2), int64(5), uint8(3)
# memory usage: 58.2 KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp     Fare  Embarked_C  \
# 0            1         0       3    1  22.0      1   7.2500           0
# 1            2         1       1    0  38.0      1  71.2833           1
# 2            3         1       3    0  26.0      0   7.9250           0
# 3            4         1       1    0  35.0      1  53.1000           0
# 4            5         0       3    1  35.0      0   8.0500           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
X = df.loc[:, df.columns.difference(['Survived'])].values
Y = df['Survived'].values

# %% [markdown]
# ### Random Forest

# %%
cv_scores=[]
for k in range(1,51, 10):
    clf = RandomForestClassifier(n_estimators=k, random_state=56, verbose=0, n_jobs=3)
    kf = KFold(n_splits=5, random_state=1, shuffle=True)
    scores = cross_val_score(clf, X, Y, cv=kf, scoring='roc_auc')
    cv_scores.append([k, scores.mean(), scores.std()])
df_scores = pd.DataFrame(cv_scores, columns=['k', 'roc_auc_score', 'STD'])

# %%
sns.lineplot(x="k", y="roc_auc_score", data=df_scores)

# %%
# %%time
rf = RandomForestClassifier(n_estimators=1, random_state=42, verbose=0, n_jobs=3)
kf = KFold(n_splits=5, random_state=42, shuffle=True)
parameters = {'n_estimators': range(50,151, 50),
              'max_depth': [1,3,5,7], 
              'min_samples_split':[2,4,6],
              'min_samples_leaf':[2,4,6] }
clf = GridSearchCV(rf, parameters, cv=kf, scoring='roc_auc')
clf.fit(X, Y)
# Out:
# Wall time: 3min 17s

# %%
clf.best_params_
# Out:
# {'max_depth': 7,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
rf_clf = clf.best_estimator_

# %%
pd.DataFrame(clf.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.092879      0.009694         0.105090        0.000496
# 1         0.136242      0.015472         0.105455        0.000367
# 2         0.162482      0.016838         0.105633        0.000198
# 3         0.102242      0.018144         0.105550        0.000437
# 4         0.135724      0.006805         0.104977        0.000972
# 5         0.164662      0.011653         0.105313        0.000253
# 6         0.099294      0.018001         0.104873        0.001245
# 7         0.141253      0.012602         0.105435        0.001053
# 8         0.153822      0.017045         0.104404        0.001369
# 9         0.091583      0.011518         0.104773        0.000862
# 10        0.139773      0.008597         0.105602        0.000378
# 11        0.190137      0.035928         0.105242        0.000403
# 12        0.100213      0.017529         0.105699        0.001658
# 13        0.130294      0.015070         0.105425        0.000160
# 14        0.163922      0.016572         0.105496        0.000133
# 78                5                      6                       6
# 79                5                      6                       6
# 80                5                      6                       6
# 81                7                      2                       2
# 82                7                      2                       2
# 83                7                      2                       2
# 84                7                      2                       4
# 85                7                      2                       4
# 86                7                      2                       4
# 87                7                      2                       6
# 88                7                      2                       6
# 89                7                      2                       6
# 90                7                      4                       2
# 91                7                      4                       2
# 92                7                      4                       2
# 93                7                      4                       4
# 94                7                      4                       4
# 95                7                      4                       4
# 96                7                      4                       6
# 97                7                      4                       6
# 98                7                      4                       6
# 99                7                      6                       2
# 100               7                      6                       2
# 101               7                      6                       2
# 102               7                      6                       4
# 103               7                      6                       4
# 104               7                      6                       4
# 105               7                      6                       6
# 106               7                      6                       6
# 107               7                      6                       6
#
#     param_n_estimators                                             params  \
# 0                   50  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 1                  100  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 2                  150  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 3                   50  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 4                  100  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 5                  150  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 6                   50  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 7                  100  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 8                  150  {'max_depth': 1, 'min_samples_leaf': 2, 'min_s...
# 9                   50  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 10                 100  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 11                 150  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 12                  50  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 13                 100  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 14                 150  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 15                  50  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 16                 100  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 17                 150  {'max_depth': 1, 'min_samples_leaf': 4, 'min_s...
# 18                  50  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 19                 100  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 20                 150  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 21                  50  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 22                 100  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 23                 150  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 24                  50  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 25                 100  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 26                 150  {'max_depth': 1, 'min_samples_leaf': 6, 'min_s...
# 27                  50  {'max_depth': 3, 'min_samples_leaf': 2, 'min_s...
# 28                 100  {'max_depth': 3, 'min_samples_leaf': 2, 'min_s...
# 29                 150  {'max_depth': 3, 'min_samples_leaf': 2, 'min_s...
# ..                 ...                                                ...
# 78                  50  {'max_depth': 5, 'min_samples_leaf': 6, 'min_s...
# 79                 100  {'max_depth': 5, 'min_samples_leaf': 6, 'min_s...
# 80                 150  {'max_depth': 5, 'min_samples_leaf': 6, 'min_s...
# 81                  50  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 82                 100  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 83                 150  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 84                  50  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 85                 100  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 86                 150  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 87                  50  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 88                 100  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 89                 150  {'max_depth': 7, 'min_samples_leaf': 2, 'min_s...
# 90                  50  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 91                 100  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 92                 150  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 93                  50  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 94                 100  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 95                 150  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 96                  50  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 97                 100  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 98                 150  {'max_depth': 7, 'min_samples_leaf': 4, 'min_s...
# 99                  50  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 100                100  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 101                150  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 102                 50  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 103                100  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 104                150  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 105                 50  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 106                100  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
# 107                150  {'max_depth': 7, 'min_samples_leaf': 6, 'min_s...
#
#      split0_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0             0.848757  ...         0.841808        0.025447               82
# 1             0.851017  ...         0.841694        0.026064               94
# 2             0.854275  ...         0.841212        0.025921              100
# 3             0.848757  ...         0.841808        0.025447               82
# 4             0.851017  ...         0.841694        0.026064               94
# 5             0.854275  ...         0.841212        0.025921              100
# 6             0.848757  ...         0.841808        0.025447               82
# 7             0.851017  ...         0.841694        0.026064               94
# 8             0.854275  ...         0.841212        0.025921              100
# 9             0.848757  ...         0.841808        0.025447               82
# 10            0.851017  ...         0.841694        0.026064               94
# 11            0.854275  ...         0.841212        0.025921              100
# 12            0.848757  ...         0.841808        0.025447               82
# 27             0.876686            0.892515          0.882174         0.005884
# 28             0.878426            0.891033          0.882725         0.004929
# 29             0.877906            0.890623          0.882737         0.004608
# ..                  ...                 ...               ...              ...
# 78             0.902633            0.916201          0.910185         0.005129
# 79             0.908026            0.916139          0.911124         0.003342
# 80             0.907472            0.918697          0.912285         0.004153
# 81             0.951656            0.957523          0.955783         0.002372
# 82             0.955841            0.958661          0.957408         0.001529
# 83             0.958026            0.958959          0.958832         0.001494
# 84             0.951656            0.957523          0.955783         0.002372
# 85             0.955841            0.958661          0.957408         0.001529
# 86             0.958026            0.958959          0.958832         0.001494
# 87             0.948159            0.955201          0.953181         0.003559
# 88             0.952541            0.956700          0.955311         0.002212
# 89             0.954101            0.957536          0.956523         0.002411
# 90             0.939458            0.945516          0.942754         0.002344
# 91             0.944104            0.947097          0.944869         0.002694
# 92             0.945086            0.948215          0.945769         0.002273
# 93             0.939458            0.945516          0.942754         0.002344
# 94             0.944104            0.947097          0.944869         0.002694
# 95             0.945086            0.948215          0.945769         0.002273
# 96             0.939458            0.945516          0.942754         0.002344
# 97             0.944104            0.947097          0.944869         0.002694
# 98             0.945086            0.948215          0.945769         0.002273
# 99             0.931114            0.934689          0.932135         0.003086
# 100            0.933303            0.937901          0.934323         0.003090
# 101            0.933923            0.938811          0.935316         0.002911
# 102            0.931114            0.934689          0.932135         0.003086
# 103            0.933303            0.937901          0.934323         0.003090
# 104            0.933923            0.938811          0.935316         0.002911
# 105            0.931114            0.934689          0.932135         0.003086
# 106            0.933303            0.937901          0.934323         0.003090
# 107            0.933923            0.938811          0.935316         0.002911
#
# [108 rows x 24 columns]

# %%
sns.lineplot(x="param_n_estimators", y="mean_test_score", data=clf.cv_results_)

# %% [markdown]
# ### GBM

# %%
cv_scores_gbm=[]
for k in range(1,351, 10):
    clf = GradientBoostingClassifier(learning_rate=1, n_estimators=k, random_state=56, verbose=0)
    kf = KFold(n_splits=5, random_state=1, shuffle=True)
    scores = cross_val_score(clf, X, Y, cv=kf, scoring='roc_auc')
    cv_scores_gbm.append([k, scores.mean(), scores.std()])
df_scores_gbm = pd.DataFrame(cv_scores_gbm, columns=['k', 'roc_auc_score', 'STD'])

# %%
sns.lineplot(x="k", y="roc_auc_score", data=df_scores_gbm)

# %%
# %%time
gbm = GradientBoostingClassifier(learning_rate=1, n_estimators=1, random_state=56, verbose=0)
kf = KFold(n_splits=5, random_state=56, shuffle=True)
parameters = {'n_estimators':range(50,501, 50),
              'learning_rate':[1, 0.5, 0.3, 0.2, 0.1], 
              'min_samples_split':[2,4,6],
              'min_samples_leaf':[2,4,6],
              'max_features':[4,5,6,7]}
clf = GridSearchCV(gbm, parameters, cv=kf, scoring='roc_auc')
clf.fit(X, Y)
# Out:
# Wall time: 26min 17s

# %%
clf.best_params_
# Out:
# {'learning_rate': 0.2,
#  'max_features': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
sns.lineplot(x="param_n_estimators", y="mean_test_score", data=clf.cv_results_)
